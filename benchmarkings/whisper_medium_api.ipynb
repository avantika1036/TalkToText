# %% [markdown]
# <a href="https://colab.research.google.com/github/KashviSharma15/talk_2_text/blob/main/whisper_medium_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install fastapi uvicorn pyngrok pydub ffmpeg-python
# !apt-get install ffmpeg -y
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-mf499xxb
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-mf499xxb
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-sdoe6wcq
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-sdoe6wcq
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...

# %%
from fastapi import FastAPI, UploadFile, File
import whisper
import shutil
import uvicorn
import os

app = FastAPI()
model = whisper.load_model("medium")  # Change to "medium" instead of large-v3

@app.post("/transcribe/")
async def transcribe(file: UploadFile = File(...)):
    with open("audio.mp3", "wb") as f:
        shutil.copyfileobj(file.file, f)

    result = model.transcribe("audio.mp3")
    os.remove("audio.mp3")
    return {"text": result["text"]}
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:09<00:00, 159MiB/s]

# %%
from pyngrok import ngrok

ngrok.set_auth_token("2yuqE3vw8mKDAunFzwKAcvoHqIo_6qcJxhzRujvGvz6bDEwv1")  # Replace with your token
ngrok.kill()
public_url = ngrok.connect(8000)
print("Your public API is:", public_url)
# Out:
# Your public API is: NgrokTunnel: "https://2391-34-87-1-86.ngrok-free.app" -> "http://localhost:8000"

# %%
import threading

def run():
    uvicorn.run(app, host="0.0.0.0", port=8000)

threading.Thread(target=run).start()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2b9426e-4cd6-4132-96c4-ce2888bb9fec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2b9426e-4cd6-4132-96c4-ce2888bb9fec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import requests

with open("audio.mp3", "rb") as f:
    response = requests.post("https://2391-34-87-1-86.ngrok-free.app/transcribe/", files={"file": f})  # Replace with actual URL

print("STATUS CODE:", response.status_code)
print("RESPONSE TEXT:", response.text)  # Show raw text output
# Out:
# INFO:     34.87.1.86:0 - "POST /transcribe/ HTTP/1.1" 200 OK
# STATUS CODE: 200
# RESPONSE TEXT: {"text":" तो आप लोगा में से कही लोगा का यह सवाल था कि निचे जो यह आटो कैप्सं जार है यह मैं कैसे आड करता हूं तो आज मैं अपको अगए से दो तरीके बताने वाला हूँ पहला तो जो मैं खुद यूस करता हूं दूसरा जिसे तूं फोन में ही ऐसे आटो कैप्सं जेनरेट कर सकते हूं पहले तरीकी के लिए तुमें चाईईओ गा पीसी क्योकि यह तरीका वर्क करता है प्रीमियर प्रो एपके अंदर पर इसमें आपको अपनी खुद परिप्ट को अच्छे से सिंक करना होता है उसके बाद आपका कैप्सं मस्ट तरीके से जेनरेट हो जाएगा दूसरा फरीका अप्लिकेशन का जो कि आपके फोन में वाक करेगा जो है आवटो कैप जिसमें आपको अपनी विडियो को सिंप्लिली अपलोड करना है और वो अपने हाँप ही आपको बहुत सारी लैंगवजेज में कैप्सं जेनरेट करके देगा"}
